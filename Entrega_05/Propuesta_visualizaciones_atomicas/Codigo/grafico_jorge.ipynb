# %%
import pandas as pd
import plotly.express as px
# Cargar la base de datos
df = pd.read_csv('/content/drive/MyDrive/Ultrapegados graficos/Bases de datos/datos_grafico.csv')

# Se agrupan los datos, realizando la suma de las reproducciones de las canciones urbanas y se añaden los nombres de
# estas canciones a una lista
df_grouped = df.groupby(['año', 'País']).agg({
    'streams': 'sum',
    'track_name': ', '.join
}).reset_index()

# Se genera un mapa de puntos con georeferenciación. Se le asigna el país de donde se extrajeron los datos, agregando los datos
# de interes como el nombre, reproducciones (la que ademas le da el tamaño al circulo) y se aumenta el tamaño de los ciruculos
fig = px.scatter_geo(
    df_grouped,
    locations="País",
    locationmode="country names",
    color="streams",
    size="streams",
    hover_name="track_name",
    animation_frame="año",
    title= "Ultrapegados: reproducción de canciones urbanas chilenas en el mundo",
    template="plotly",
    projection="natural earth",
    size_max=100,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f3beabff-1ae4-45df-a28b-7b4e05431656" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3beabff-1ae4-45df-a28b-7b4e05431656")) {                    Plotly.newPlot(                        "f3beabff-1ae4-45df-a28b-7b4e05431656",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ea\u00f1o=2020\u003cbr\u003estreams=%{marker.color}\u003cbr\u003ePa\u00eds=%{location}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Tak Tiki Tak","Tak Tiki Tak, Goteo","Tak Tiki Tak","Tak Tiki Tak","Tak Tiki Tak","Tak Tiki Tak","Tak Tiki Tak","Tak Tiki Tak","Tak Tiki Tak"],"legendgroup":"","locationmode":"country names","locations":["Argentina","Chile","Colombia","Global","Guatemala","Honduras","M\u00e9xico","Per\u00fa","Spain"],"marker":{"color":[1084112,1060130,258626,7367064,115780,32834,2234782,399468,1109957],"coloraxis":"coloraxis","size":[1084112,1060130,258626,7367064,115780,32834,2234782,399468,1109957],"sizemode":"area","sizeref":3538.7501,"symbol":"circle"},"mode":"markers","name":"","showlegend":false,"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity ...
